# %%
import requests
import pandas as pd

# %%
root="https://api-adresse.data.gouv.fr/search/"
key="?q="
address="88+bd+du+port"

req=requests.get("{}{}{}".format(root,key,address))

df= pd.json_normalize(req.json()["features"]) # permet de convertir un json en dataframe , req.json renvoie le json 
df
# Out:
#       type geometry.type     geometry.coordinates  \
# 0  Feature         Point    [2.063623, 49.032152]
# 1  Feature         Point     [2.290695, 49.89774]
# 2  Feature         Point    [3.607003, 43.424148]
# 3  Feature         Point  [45.160161, -12.733779]
# 4  Feature         Point    [3.036603, 42.792083]
#
#                       properties.label  properties.score properties.id  \
# 0        Boulevard du Port 95000 Cergy          0.388910    95127_1448
# 1       Boulevard du Port 80000 Amiens          0.388806    80021_6590
# 2         Boulevard du Port 34140 Mèze          0.383753    34157_0770
# 3      Boulevard du Port 97600 Koungou          0.382592    97610_3111
# 4  Boulevard du Port 66420 Le Barcarès          0.377890    66017_0249
#
#      properties.name properties.postcode properties.citycode  properties.x  \
# 0  Boulevard du Port               95000               95127     631527.62
# 1  Boulevard du Port               80000               80021     648996.81
# 2  Boulevard du Port               34140               34157     749176.87
# 3  Boulevard du Port               97600               97610     517386.42
# 4  Boulevard du Port               66420               66017     702998.03
#
#    properties.y properties.city                  properties.context  \
# 0    6881768.37           Cergy       95, Val-d'Oise, Île-de-France
# 1    6977899.92          Amiens          80, Somme, Hauts-de-France
# 2    6258526.37            Mèze              34, Hérault, Occitanie
# 3    8592299.00         Koungou                        976, Mayotte
# 4    6188063.58     Le Barcarès  66, Pyrénées-Orientales, Occitanie
#
#   properties.type  properties.importance  properties.street  \
# 0          street                0.67801  Boulevard du Port
# 1          street                0.67687  Boulevard du Port
# 2          street                0.62128  Boulevard du Port
# 3          street                0.60851  Boulevard du Port
# 4          street                0.55679  Boulevard du Port
#
#                        properties.banId
# 0                                   NaN
# 1                                   NaN
# 2  5cb068cd-c926-4356-94a8-5980aead54c7
# 3  1a781702-05d4-4c91-9e6e-49936ffd8808
# 4                                   NaN
